# %% [markdown]
# # Read in the Jungle/Mid/Top data into the database

# %%
import json
json_data = open('output.json').read()
data = json.loads(json_data)

# All the loops!
for item in data:
    role = item['role']
    if (role == "JUNGLE" or role == "TOP" or role == "MIDDLE"):
        arr = item['matchups'][role]
        champion_id = item['championId']
        for x in arr:
            if (x['count'] < 21):
                continue
            if (x['champ1_id'] == champion_id):
                winrate = x['champ1']['winrate']
            else:
                winrate = x['champ2']['winrate']        
            enemy_champion = x['champ2_id']
            print(winrate)
            ## SAVE: champion,enemy_champion,winrate,role
            
        
# Save to DB the information
# Out:
# 64
# 141
# 0.4990791896869245
# 79
# 0.4581889081455806
# 121
# 0.46540056756166776
# 64
# 0.44623927309439676
# 64
# 0.483072546230441
# 113
# 0.43355534411671426
# 64
# 0.463302752293578
# 64
# 0.48183908045977014
# 64
# 0.4521276595744681
# 421
# 0.45157657657657657
# 64
# 0.4220129487934079
# 254
# 0.4716859716859717
# 154
# 0.5036838580040187
# 76
# 0.47046843177189407
# 64
# 0.4658151765589782
# 64
# 0.43125
# 104
# 0.5302521008403361
# 64
# 0.4473916887709991
# 64
# 0.4850467289719626
# 64
# 0.4447646493756004
# 107
# 0.47466390899689764
# 102
# 0.4420368364030336
# 64
# 0.4359255202628697
# 120
# 0.49883720930232556
# 64
# 0.46949602122015915
# 64
# 0.4933510638297872
# 64
# 0.4223826714801444
# 64
# 0.43520309477756286
# 203
# 0.487551867219917
# 427
# 0.41841004184100417
# 64
# 0.3954022988505747
# 64
# 0.4891304347826087
# 64
# 0.4838709677419355
# 80
# 0.46325878594249204
# 131
# 0.52
# 72
# 0.44912280701754387
# 106
# 0.48333333333333334
# 68
# 0.5126050420168067
# 77
# 0.4396135265700483
# 64
# 0.4846938775510204
# 78
# 0.4648648648648649
# 111
# 0.5446428571428571
# 141
# 141
# 0.5009208103130756
# 141
# 0.4822906322409798
# 141
# 0.4768734313373969
# 141
# 0.4650799843932891
# 141
# 0.46664034741413346
# 141
# 0.47560975609756095
# 141
# 0.45737704918032784
# 141
# 0.4765886287625418
# 141
# 0.47309284447072736
# 141
# 0.4313319530710835
# 154
# 0.5249169435215947
# 254
# 0.479108635097493
# 421
# 0.476280834914611
# 141
# 0.487360970677452
# 141
# 0.4645760743321719
# 141
# 0.4769775678866588
# 141
# 0.4919454770755886
# 141
# 0.48672566371681414
# 141
# 0.49226804123711343
# 141
# 0.49477806788511747
# 141
# 0.4810810810810811
# 141
# 0.5169491525423728
# 141
# 0.4924698795180723
# 141
# 0.4907120743034056
# 141
# 0.49353049907578556
# 141
# 0.4894837476099426
# 141
# 0.4864864864864865
# 141
# 0.43989071038251365
# 203
# 0.4794520547945205
# 141
# 0.48623853211009177
# 427
# 0.4228395061728395
# 141
# 0.5279503105590062
# 141
# 0.5120274914089347
# 141
# 0.4962686567164179
# 141
# 0.508695652173913
# 141
# 0.4423963133640553
# 141
# 0.47643979057591623
# 141
# 0.484472049689441
# 141
# 0.44871794871794873
# 141
# 0.38461538461538464
# 141
# 0.5462184873949579
# 141
# 0.6206896551724138
# 61
# 103
# 0.47916041979010493
# 61
# 0.4541414141414141
# 134
# 0.4883277751310148
# 238
# 0.47041420118343197
# 61
# 0.48105864037363777
# 90
# 0.4905897114178168
# 61
# 0.5052910052910053
# 99
# 0.48261758691206547
# 157
# 0.48911465892597966
# 163
# 0.5023219814241486
# 61
# 0.44366197183098594
# 61
# 0.442246835443038
# 245
# 0.4925986842105263
# 61
# 0.4970906068162926
# 236
# 0.514919011082694
# 112
# 0.5312232677502139
# 105
# 0.487279843444227
# 61
# 0.5126135216952573
# 69
# 0.5076608784473953
# 115
# 0.44175824175824174
# 61
# 0.48924122310305773
# 161
# 0.44733727810650886
# 101
# 0.453781512605042
# 91
# 0.4513031550068587
# 61
# 0.4608433734939759
# 131
# 0.45964912280701753
# 268
# 0.5399239543726235
# 126
# 0.4605809128630705
# 63
# 0.5176991150442478
# 61
# 0.4435028248587571
# 61
# 0.48424068767908307
# 61
# 0.48502994011976047
# 136
# 0.4074074074074074
# 61
# 0.41455696202531644
# 61
# 0.511326860841424
# 61
# 0.5179153094462541
# 127
# 0.4750830564784053
# 84
# 0.47717842323651455
# 61
# 0.4778761061946903
# 61
# 0.45454545454545453
# 61
# 0.5783132530120482
# 74
# 0.47619047619047616
# 85
# 0.5333333333333333
# 61
# 0.53125

# %%
import json
import mysql.connector
from run_sql_utility.run_sql_utility import *

################################################################################

def readInChampions(local_cnx):
    json_data = open('champ_ids.json').read()
    data = json.loads(json_data)['data']
    for key in data:
        print(key['name'])
        print(key['id'])
        
    print(data)

################################################################################

config_local = {
    'user': "root",
    'password': "",
    'host': '127.0.0.1',
    'database': 'gg',
    'port': 3306
}

################################################################################

print("connecting.")
local_cnx = mysql.connector.connect(**config_local)
print("connection done.")
try:
    cur = local_cnx.cursor()
    # Truncate the table each script run.
    cur.execute("""DELETE FROM champions""")

    readInChampions(local_cnx)
    print( "Script Success!" )
except mysql.connector.Error as err:
    print("Something went wrong: {}".format(err))
finally:
    local_cnx.close()
# Out:
# connecting.
# connection done.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-ec38252c19f3> in <module>()
#      34     cur.execute("""DELETE FROM champions""")
#      35
# ---> 36     readInChampions(local_cnx)
#      37     print( "Script Success!" )
#      38 except mysql.connector.Error as err:
#
# <ipython-input-7-ec38252c19f3> in readInChampions(local_cnx)
#       9     data = json.loads(json_data)['data']
#      10     for key in data:
# ---> 11         print(key['name'])
#      12         print(key['id'])
#      13         print(data[key])
#
# TypeError: string indices must be integers
